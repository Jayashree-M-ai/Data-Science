# %%
import pandas as pd
from scipy.stats import ttest_ind

data = pd.DataFrame({'Group': ['A', 'A', 'B', 'B'], 'Score': [70, 80, 85, 90]})

group_A = data[data['Group'] == 'A']['Score']
group_B = data[data['Group'] == 'B']['Score']

t_stat, p_value = ttest_ind(group_A, group_B, axis=1)
print(f"T-Statistic: {t_stat}, P-Value: {p_value}")

# %%
import pandas as pd
from scipy.stats import ttest_ind

data = pd.DataFrame({'Group': ['A', 'A', 'B', 'B'], 'Score': [70, 80, 85, 90]})

group_A = data[data['Group'] == 'A']['Score']
group_B = data[data['Group'] == 'B']['Score']

t_stat, p_value = ttest_ind(group_A, group_B)
print(f"T-Statistic: {t_stat}, P-Value: {p_value}")
# Out:
# T-Statistic: -2.23606797749979, P-Value: 0.1548457452714834

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3, 4], 'B': [4, 3, 2, 1]})
correlation = df.corr(method='spearman')
print("Correlation Coefficient:", correlation[0][1])

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3, 4], 'B': [4, 3, 2, 1]})
correlation = df.corr(method='spearman')
print("Correlation Coefficient:", correlation)
# Out:
# Correlation Coefficient:      A    B
# A  1.0 -1.0
# B -1.0  1.0

# %%
import pandas as pd

data = pd.DataFrame({'Name': ['Alice', 'Bob', None, 'David'],
                      'Age': [25, 30, 22, None]})

data = data.dropna('rows')
print(data)

# %%
import pandas as pd

data = pd.DataFrame({'Name': ['Alice', 'Bob', None, 'David'],
                      'Age': [25, 30, 22, None]})

data = data.dropna(axis=0)
print(data)
# Out:
#     Name   Age
# 0  Alice  25.0
# 1    Bob  30.0

# %%
import pandas as pd
from scipy.stats import f_oneway

data = pd.DataFrame({
    'Course': ['Math', 'Math', 'Science', 'Science', 'English', 'English', 'Math', 'Science', 'English'],
    'Marks': [65, 70, 85, 80, 60, 75, 72, 90, 68]
})

f_stat, p_value = f_oneway(data['Marks'])
print("F-Statistic:", f_stat)
print("P-Value:", p_value)

# %%
import pandas as pd
from scipy.stats import f_oneway

df = pd.DataFrame({
    'Course': ['Math', 'Math', 'Science', 'Science', 'English', 'English', 'Math', 'Science', 'English'],
    'Marks': [65, 70, 85, 80, 60, 75, 72, 90, 68]
})
m=df.loc[df['Course']=='Math','Marks']
s=df.loc[df['Course']=='Science','Marks']
e=df.loc[df['Course']=='English','Marks']
f_stat, p_value = f_oneway(m,s,e)
print("F-Statistic:", f_stat)
print("P-Value:", p_value)
# Out:
# F-Statistic: 8.876325088339225
# P-Value: 0.016118236853147873

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = np.random.normal(50, 10, 1000)

plt.hist()
plt.title("PDF Plot")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = np.random.normal(50, 10, 1000)

plt.hist(data)
plt.title("PDF Plot")
plt.show()
